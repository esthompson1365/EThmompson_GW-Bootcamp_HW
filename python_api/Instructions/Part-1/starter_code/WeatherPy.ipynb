# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
# output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 599

# %%
api_key = "338f9081c7fd83efee7f5204ba4b2c6a"

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 

# List of city data
city_data = []

# Print to logger
print("Start Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
# Out:
# Start Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | qaanaaq
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | isangel
# Processing Record 5 of Set 1 | kulebaki
# Processing Record 6 of Set 1 | carnarvon
# Processing Record 7 of Set 1 | ponta do sol
# Processing Record 8 of Set 1 | neftcala
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | khatanga
# Processing Record 11 of Set 1 | usila
# City not found. Skipping...
# Processing Record 12 of Set 1 | flinders
# Processing Record 13 of Set 1 | tuktoyaktuk
# Processing Record 14 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 1 | cabo san lucas
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | pevek
# Processing Record 18 of Set 1 | butaritari
# Processing Record 19 of Set 1 | asau
# City not found. Skipping...
# Processing Record 20 of Set 1 | padang
# Processing Record 21 of Set 1 | clyde river
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | vaini
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | toora-khem
# Processing Record 26 of Set 1 | mount gambier
# Processing Record 27 of Set 1 | mar del plata
# Processing Record 28 of Set 1 | lekoni
# Processing Record 29 of Set 1 | kapaa
# Processing Record 30 of Set 1 | wanning
# Processing Record 31 of Set 1 | hilo
# Processing Record 32 of Set 1 | moussoro
# Processing Record 33 of Set 1 | alofi
# Processing Record 34 of Set 1 | georgetown
# Processing Record 35 of Set 1 | nikolskoye
# Processing Record 36 of Set 1 | geraldton
# Processing Record 37 of Set 1 | victoria
# Processing Record 38 of Set 1 | atuona
# Processing Record 39 of Set 1 | neuquen
# Processing Record 40 of Set 1 | salinas
# Processing Record 41 of Set 1 | okha
# Processing Record 42 of Set 1 | jacareacanga
# Processing Record 43 of Set 1 | lorengau
# Processing Record 44 of Set 1 | coahuayana
# Processing Record 45 of Set 1 | saint-francois
# Processing Record 46 of Set 1 | abashiri
# Processing Record 47 of Set 1 | nanortalik
# Processing Record 48 of Set 1 | saldanha
# Processing Record 49 of Set 1 | port alfred
# Processing Record 50 of Set 1 | lamesa
# Processing Record 0 of Set 2 | mataura
# Processing Record 1 of Set 2 | busselton
# Processing Record 2 of Set 2 | pisco
# Processing Record 3 of Set 2 | ipanema
# Processing Record 4 of Set 2 | sola
# Processing Record 5 of Set 2 | manadhoo
# Processing Record 6 of Set 2 | reporoa
# Processing Record 7 of Set 2 | bambous virieux
# Processing Record 8 of Set 2 | new norfolk
# Processing Record 9 of Set 2 | brownsville
# Processing Record 10 of Set 2 | roma
# Processing Record 11 of Set 2 | east london
# Processing Record 12 of Set 2 | yulara
# Processing Record 13 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 14 of Set 2 | tirumullaivasal
# Processing Record 15 of Set 2 | panama city
# Processing Record 16 of Set 2 | portmore
# Processing Record 17 of Set 2 | nizhniy odes
# Processing Record 18 of Set 2 | valparaiso
# Processing Record 19 of Set 2 | dien bien
# City not found. Skipping...
# Processing Record 20 of Set 2 | bonfim
# Processing Record 21 of Set 2 | yellowknife
# Processing Record 22 of Set 2 | albany
# Processing Record 23 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 2 | athol
# Processing Record 25 of Set 2 | dovolnoye
# Processing Record 26 of Set 2 | jamestown
# Processing Record 27 of Set 2 | acapulco
# Processing Record 28 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 2 | bluff
# Processing Record 30 of Set 2 | pemberton
# Processing Record 31 of Set 2 | norman wells
# Processing Record 32 of Set 2 | coihaique
# Processing Record 33 of Set 2 | thompson
# Processing Record 34 of Set 2 | hobart
# Processing Record 35 of Set 2 | manggar
# Processing Record 36 of Set 2 | miles city
# Processing Record 37 of Set 2 | port elizabeth
# Processing Record 38 of Set 2 | margate
# Processing Record 39 of Set 2 | tuatapere
# Processing Record 40 of Set 2 | chokurdakh
# Processing Record 41 of Set 2 | hithadhoo
# Processing Record 42 of Set 2 | kyshtovka
# Processing Record 43 of Set 2 | westport
# Processing Record 44 of Set 2 | pahrump
# Processing Record 45 of Set 2 | san patricio
# Processing Record 46 of Set 2 | katsuura
# Processing Record 47 of Set 2 | karauzyak
# City not found. Skipping...
# Processing Record 48 of Set 2 | san bartolome
# Processing Record 49 of Set 2 | beringovskiy
# Processing Record 0 of Set 3 | saint-philippe
# Processing Record 1 of Set 3 | lasa
# Processing Record 2 of Set 3 | concordia
# Processing Record 3 of Set 3 | ribeira grande
# Processing Record 4 of Set 3 | uberlandia
# Processing Record 5 of Set 3 | concepcion
# Processing Record 6 of Set 3 | udachnyy
# Processing Record 7 of Set 3 | dingle
# Processing Record 8 of Set 3 | aykhal
# Processing Record 9 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 10 of Set 3 | halifax
# Processing Record 11 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 3 | saint george
# Processing Record 14 of Set 3 | santa marta de tormes
# Processing Record 15 of Set 3 | avarua
# Processing Record 16 of Set 3 | fukue
# Processing Record 17 of Set 3 | guerrero negro
# Processing Record 18 of Set 3 | novopavlovka
# Processing Record 19 of Set 3 | zhangjiakou
# Processing Record 20 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 3 | longyearbyen
# Processing Record 22 of Set 3 | keflavik
# Processing Record 23 of Set 3 | beloha
# Processing Record 24 of Set 3 | santa maria
# Processing Record 25 of Set 3 | asyut
# Processing Record 26 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 3 | atar
# Processing Record 28 of Set 3 | barrow
# Processing Record 29 of Set 3 | tarko-sale
# Processing Record 30 of Set 3 | lavrentiya
# Processing Record 31 of Set 3 | ironton
# Processing Record 32 of Set 3 | valverde del camino
# Processing Record 33 of Set 3 | damghan
# Processing Record 34 of Set 3 | sturgeon bay
# Processing Record 35 of Set 3 | olafsvik
# City not found. Skipping...
# Processing Record 36 of Set 3 | tupik
# Processing Record 37 of Set 3 | tasiilaq
# Processing Record 38 of Set 3 | arraial do cabo
# Processing Record 39 of Set 3 | paita
# Processing Record 40 of Set 3 | grand gaube
# Processing Record 41 of Set 3 | esperance
# Processing Record 42 of Set 3 | cockburn town
# Processing Record 43 of Set 3 | besikduzu
# Processing Record 44 of Set 3 | provideniya
# Processing Record 45 of Set 3 | bandarbeyla
# Processing Record 46 of Set 3 | nhulunbuy
# Processing Record 47 of Set 3 | pangnirtung
# Processing Record 48 of Set 3 | hermanus
# Processing Record 49 of Set 3 | kodiak
# Processing Record 0 of Set 4 | chiredzi
# Processing Record 1 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 4 | egvekinot
# Processing Record 3 of Set 4 | faya
# Processing Record 4 of Set 4 | san cristobal
# Processing Record 5 of Set 4 | tiksi
# Processing Record 6 of Set 4 | castro
# Processing Record 7 of Set 4 | srednekolymsk
# Processing Record 8 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 4 | saint-joseph
# Processing Record 10 of Set 4 | missoula
# Processing Record 11 of Set 4 | kruisfontein
# Processing Record 12 of Set 4 | mangrol
# Processing Record 13 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 4 | sobolevo
# Processing Record 15 of Set 4 | sayat
# Processing Record 16 of Set 4 | labuhan
# Processing Record 17 of Set 4 | derzhavinsk
# Processing Record 18 of Set 4 | san jose
# Processing Record 19 of Set 4 | ahipara
# Processing Record 20 of Set 4 | chuy
# Processing Record 21 of Set 4 | ghanzi
# Processing Record 22 of Set 4 | oppdal
# Processing Record 23 of Set 4 | byron bay
# Processing Record 24 of Set 4 | san borja
# Processing Record 25 of Set 4 | marsh harbour
# Processing Record 26 of Set 4 | athabasca
# Processing Record 27 of Set 4 | labuan
# Processing Record 28 of Set 4 | praia da vitoria
# Processing Record 29 of Set 4 | flores da cunha
# Processing Record 30 of Set 4 | ilulissat
# Processing Record 31 of Set 4 | taltal
# Processing Record 32 of Set 4 | kahului
# Processing Record 33 of Set 4 | vardo
# Processing Record 34 of Set 4 | ola
# Processing Record 35 of Set 4 | whitecourt
# Processing Record 36 of Set 4 | sitka
# Processing Record 37 of Set 4 | torbay
# Processing Record 38 of Set 4 | severo-kurilsk
# Processing Record 39 of Set 4 | pacific grove
# Processing Record 40 of Set 4 | aklavik
# Processing Record 41 of Set 4 | lompoc
# Processing Record 42 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 4 | zhanaozen
# Processing Record 44 of Set 4 | hualmay
# Processing Record 45 of Set 4 | mahebourg
# Processing Record 46 of Set 4 | faanui
# Processing Record 47 of Set 4 | sucua
# Processing Record 48 of Set 4 | arlit
# Processing Record 49 of Set 4 | takoradi
# Processing Record 0 of Set 5 | nikolsk
# Processing Record 1 of Set 5 | souillac
# Processing Record 2 of Set 5 | saskylakh
# Processing Record 3 of Set 5 | kununurra
# Processing Record 4 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 5 of Set 5 | monrovia
# Processing Record 6 of Set 5 | kachikau
# City not found. Skipping...
# Processing Record 7 of Set 5 | progreso
# Processing Record 8 of Set 5 | bayji
# Processing Record 9 of Set 5 | chama
# Processing Record 10 of Set 5 | kathu
# Processing Record 11 of Set 5 | abha
# Processing Record 12 of Set 5 | borama
# City not found. Skipping...
# Processing Record 13 of Set 5 | uvinza
# Processing Record 14 of Set 5 | husavik
# Processing Record 15 of Set 5 | voyvozh
# Processing Record 16 of Set 5 | bubaque
# Processing Record 17 of Set 5 | port blair
# Processing Record 18 of Set 5 | namibe
# Processing Record 19 of Set 5 | kropotkin
# Processing Record 20 of Set 5 | bethel
# Processing Record 21 of Set 5 | waipawa
# Processing Record 22 of Set 5 | komsomolskiy
# Processing Record 23 of Set 5 | grindavik
# Processing Record 24 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 5 | muros
# Processing Record 26 of Set 5 | anito
# Processing Record 27 of Set 5 | mutsamudu
# City not found. Skipping...
# Processing Record 28 of Set 5 | quepos
# Processing Record 29 of Set 5 | khani
# Processing Record 30 of Set 5 | bilibino
# Processing Record 31 of Set 5 | christchurch
# Processing Record 32 of Set 5 | mungwi
# Processing Record 33 of Set 5 | mizusawa
# Processing Record 34 of Set 5 | upernavik
# Processing Record 35 of Set 5 | kutum
# Processing Record 36 of Set 5 | banda aceh
# Processing Record 37 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 38 of Set 5 | galle
# Processing Record 39 of Set 5 | portland
# Processing Record 40 of Set 5 | cody
# Processing Record 41 of Set 5 | mao
# Processing Record 42 of Set 5 | ciudad dario
# Processing Record 43 of Set 5 | akyab
# City not found. Skipping...
# Processing Record 44 of Set 5 | dinguiraye
# Processing Record 45 of Set 5 | shellbrook
# Processing Record 46 of Set 5 | lata
# Processing Record 47 of Set 5 | shimoda
# Processing Record 48 of Set 5 | constitucion
# Processing Record 49 of Set 5 | vao
# Processing Record 0 of Set 6 | dikson
# Processing Record 1 of Set 6 | sambava
# Processing Record 2 of Set 6 | korla
# City not found. Skipping...
# Processing Record 3 of Set 6 | inongo
# Processing Record 4 of Set 6 | dali
# Processing Record 5 of Set 6 | maralal
# Processing Record 6 of Set 6 | rocha
# Processing Record 7 of Set 6 | khovu-aksy
# Processing Record 8 of Set 6 | coquimbo
# Processing Record 9 of Set 6 | krasnoselkup
# City not found. Skipping...
# Processing Record 10 of Set 6 | cherskiy
# Processing Record 11 of Set 6 | talnakh
# Processing Record 12 of Set 6 | makakilo city
# Processing Record 13 of Set 6 | khormuj
# City not found. Skipping...
# Processing Record 14 of Set 6 | ngunguru
# Processing Record 15 of Set 6 | listvyagi
# Processing Record 16 of Set 6 | mokrous
# Processing Record 17 of Set 6 | kudahuvadhoo
# Processing Record 18 of Set 6 | cacoal
# Processing Record 19 of Set 6 | burica
# City not found. Skipping...
# Processing Record 20 of Set 6 | alakurtti
# Processing Record 21 of Set 6 | teahupoo
# Processing Record 22 of Set 6 | cumpas
# Processing Record 23 of Set 6 | fayaoue
# Processing Record 24 of Set 6 | qeshm
# Processing Record 25 of Set 6 | bereda
# Processing Record 26 of Set 6 | laguna
# Processing Record 27 of Set 6 | bengkulu
# City not found. Skipping...
# Processing Record 28 of Set 6 | tiznit
# Processing Record 29 of Set 6 | bukama
# Processing Record 30 of Set 6 | mirabad
# Processing Record 31 of Set 6 | imbituba
# Processing Record 32 of Set 6 | karratha
# Processing Record 33 of Set 6 | kiruna
# Processing Record 34 of Set 6 | yokkaichi
# Processing Record 35 of Set 6 | dezhou
# Processing Record 36 of Set 6 | vagur
# Processing Record 37 of Set 6 | standerton
# Processing Record 38 of Set 6 | college
# Processing Record 39 of Set 6 | samarai
# Processing Record 40 of Set 6 | tutoia
# Processing Record 41 of Set 6 | fortuna
# Processing Record 42 of Set 6 | juru
# Processing Record 43 of Set 6 | katherine
# Processing Record 44 of Set 6 | yushala
# Processing Record 45 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 46 of Set 6 | kalmunai
# Processing Record 47 of Set 6 | qaqortoq
# Processing Record 48 of Set 6 | kaitangata
# Processing Record 49 of Set 6 | port macquarie
# Processing Record 0 of Set 7 | satis
# Processing Record 1 of Set 7 | hauterive
# Processing Record 2 of Set 7 | acajutla
# Processing Record 3 of Set 7 | galgani
# City not found. Skipping...
# Processing Record 4 of Set 7 | bam
# Processing Record 5 of Set 7 | atambua
# Processing Record 6 of Set 7 | cananeia
# Processing Record 7 of Set 7 | santa fe
# Processing Record 8 of Set 7 | vila franca do campo
# Processing Record 9 of Set 7 | la ronge
# Processing Record 10 of Set 7 | haines junction
# Processing Record 11 of Set 7 | lalibela
# Processing Record 12 of Set 7 | hasaki
# Processing Record 13 of Set 7 | sangar
# Processing Record 14 of Set 7 | le vauclin
# Processing Record 15 of Set 7 | rantepao
# Processing Record 16 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 7 | henties bay
# Processing Record 19 of Set 7 | nestorion
# City not found. Skipping...
# Processing Record 20 of Set 7 | monte alegre de minas
# Processing Record 21 of Set 7 | airai
# Processing Record 22 of Set 7 | taoudenni
# Processing Record 23 of Set 7 | mahadday weyne
# City not found. Skipping...
# Processing Record 24 of Set 7 | ingham
# Processing Record 25 of Set 7 | lamu
# Processing Record 26 of Set 7 | saint-pierre
# Processing Record 27 of Set 7 | pinheiro machado
# Processing Record 28 of Set 7 | funehiki
# Processing Record 29 of Set 7 | felipe carrillo puerto
# Processing Record 30 of Set 7 | solnechnyy
# Processing Record 31 of Set 7 | sao gabriel da cachoeira
# Processing Record 32 of Set 7 | villarrica
# Processing Record 33 of Set 7 | san rafael del sur
# Processing Record 34 of Set 7 | bom jesus da lapa
# Processing Record 35 of Set 7 | poronaysk
# Processing Record 36 of Set 7 | shabqadar
# Processing Record 37 of Set 7 | fallon
# Processing Record 38 of Set 7 | rawson
# Processing Record 39 of Set 7 | fomboni
# Processing Record 40 of Set 7 | iqaluit
# Processing Record 41 of Set 7 | santa ana
# Processing Record 42 of Set 7 | vila velha
# Processing Record 43 of Set 7 | zhengjiatun
# Processing Record 44 of Set 7 | rolim de moura
# City not found. Skipping...
# Processing Record 45 of Set 7 | leningradskiy
# Processing Record 46 of Set 7 | okato
# Processing Record 47 of Set 7 | angoche
# Processing Record 48 of Set 7 | betsiamites
# Processing Record 49 of Set 7 | yerbogachen
# Processing Record 0 of Set 8 | gizo
# Processing Record 1 of Set 8 | zlynka
# Processing Record 2 of Set 8 | hobyo
# Processing Record 3 of Set 8 | codrington
# Processing Record 4 of Set 8 | lebu
# Processing Record 5 of Set 8 | belebey
# Processing Record 6 of Set 8 | manta
# Processing Record 7 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 8 | kaohsiung
# Processing Record 9 of Set 8 | kirakira
# Processing Record 10 of Set 8 | novyy urengoy
# Processing Record 11 of Set 8 | carutapera
# Processing Record 12 of Set 8 | klaksvik
# Processing Record 13 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 14 of Set 8 | acari
# Processing Record 15 of Set 8 | menongue
# Processing Record 16 of Set 8 | karaton
# Processing Record 17 of Set 8 | langsa
# Processing Record 18 of Set 8 | paamiut
# Processing Record 19 of Set 8 | podor
# Processing Record 20 of Set 8 | luena
# Processing Record 21 of Set 8 | yenagoa
# Processing Record 22 of Set 8 | bathsheba
# Processing Record 23 of Set 8 | neepawa
# Processing Record 24 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 8 | cidreira
# Processing Record 26 of Set 8 | santa rosa
# Processing Record 27 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 8 | vostok
# Processing Record 29 of Set 8 | san quintin
# Processing Record 30 of Set 8 | acarau
# City not found. Skipping...
# Processing Record 31 of Set 8 | talara
# Processing Record 32 of Set 8 | andros
# Processing Record 33 of Set 8 | grand island
# Processing Record 34 of Set 8 | moose factory
# Processing Record 35 of Set 8 | astorga
# Processing Record 36 of Set 8 | praia
# Processing Record 37 of Set 8 | pingzhuang
# City not found. Skipping...
# Processing Record 38 of Set 8 | grand forks
# Processing Record 39 of Set 8 | ampanihy
# Processing Record 40 of Set 8 | ancud
# Processing Record 41 of Set 8 | kapoeta
# City not found. Skipping...
# Processing Record 42 of Set 8 | aksarayskiy
# Processing Record 43 of Set 8 | gidole
# Processing Record 44 of Set 8 | kimbe
# Processing Record 45 of Set 8 | chumikan
# Processing Record 46 of Set 8 | sept-iles
# Processing Record 47 of Set 8 | carupano
# Processing Record 48 of Set 8 | bourail
# Processing Record 49 of Set 8 | bodden town
# Processing Record 0 of Set 9 | erenhot
# Processing Record 1 of Set 9 | marsabit
# Processing Record 2 of Set 9 | kalanchak
# Processing Record 3 of Set 9 | atbasar
# Processing Record 4 of Set 9 | lanivtsi
# Processing Record 5 of Set 9 | aligudarz
# Processing Record 6 of Set 9 | hohhot
# Processing Record 7 of Set 9 | mattru
# Processing Record 8 of Set 9 | kidal
# Processing Record 9 of Set 9 | eydhafushi
# Processing Record 10 of Set 9 | anloga
# Processing Record 11 of Set 9 | puerto narino
# Processing Record 12 of Set 9 | hambantota
# Processing Record 13 of Set 9 | port hardy
# Processing Record 14 of Set 9 | gondanglegi
# Processing Record 15 of Set 9 | skjervoy
# Processing Record 16 of Set 9 | los llanos de aridane
# Processing Record 17 of Set 9 | lakes entrance
# Processing Record 18 of Set 9 | saint-augustin
# Processing Record 19 of Set 9 | devonport
# Processing Record 20 of Set 9 | port hedland
# Processing Record 21 of Set 9 | dunedin
# Processing Record 22 of Set 9 | mangan
# Processing Record 23 of Set 9 | nabire
# Processing Record 24 of Set 9 | sinjah
# City not found. Skipping...
# Processing Record 25 of Set 9 | birao
# Processing Record 26 of Set 9 | pimentel
# Processing Record 27 of Set 9 | shawinigan
# Processing Record 28 of Set 9 | broken hill
# Processing Record 29 of Set 9 | newport
# Processing Record 30 of Set 9 | kyritz
# Processing Record 31 of Set 9 | vieques
# Processing Record 32 of Set 9 | simao
# Processing Record 33 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 34 of Set 9 | wawina
# City not found. Skipping...
# Processing Record 35 of Set 9 | two hills
# Processing Record 36 of Set 9 | ainring
# Processing Record 37 of Set 9 | zurrieq
# Processing Record 38 of Set 9 | hit
# Processing Record 39 of Set 9 | yelizovo
# Processing Record 40 of Set 9 | lulea
# Processing Record 41 of Set 9 | sistranda
# Processing Record 42 of Set 9 | bezerros
# Processing Record 43 of Set 9 | sumbawa
# City not found. Skipping...
# Processing Record 44 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 45 of Set 9 | port lincoln
# Processing Record 46 of Set 9 | salinopolis
# Processing Record 47 of Set 9 | talaya
# Processing Record 48 of Set 9 | oyama
# Processing Record 49 of Set 9 | yamada
# Processing Record 0 of Set 10 | rio gallegos
# Processing Record 1 of Set 10 | jining
# Processing Record 2 of Set 10 | suihua
# Processing Record 3 of Set 10 | gazanjyk
# Processing Record 4 of Set 10 | mlyniv
# Processing Record 5 of Set 10 | thinadhoo
# Processing Record 6 of Set 10 | gasa
# Processing Record 7 of Set 10 | jumla
# Processing Record 8 of Set 10 | kitgum
# Processing Record 9 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 10 | manbij
# Processing Record 11 of Set 10 | beterou
# Processing Record 12 of Set 10 | teguldet
# Processing Record 13 of Set 10 | suhut
# Processing Record 14 of Set 10 | senj
# Processing Record 15 of Set 10 | kjollefjord
# Processing Record 16 of Set 10 | puka
# Processing Record 17 of Set 10 | nobres
# Processing Record 18 of Set 10 | vuktyl
# Processing Record 19 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 10 | qandala
# Processing Record 21 of Set 10 | aljezur
# Processing Record 22 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 23 of Set 10 | tadine
# Processing Record 24 of Set 10 | loiza
# Processing Record 25 of Set 10 | tessalit
# Processing Record 26 of Set 10 | mehamn
# Processing Record 27 of Set 10 | verkhoyansk
# Processing Record 28 of Set 10 | rybinsk
# Processing Record 29 of Set 10 | pochutla
# Processing Record 30 of Set 10 | lisakovsk
# Processing Record 31 of Set 10 | bogale
# Processing Record 32 of Set 10 | north bend
# Processing Record 33 of Set 10 | nishihara
# Processing Record 34 of Set 10 | kavaratti
# Processing Record 35 of Set 10 | rabo de peixe
# Processing Record 36 of Set 10 | can
# Processing Record 37 of Set 10 | touros
# Processing Record 38 of Set 10 | wagar
# Processing Record 39 of Set 10 | requena
# Processing Record 40 of Set 10 | phonhong
# Processing Record 41 of Set 10 | tual
# Processing Record 42 of Set 10 | fairbanks
# Processing Record 43 of Set 10 | caravelas
# Processing Record 44 of Set 10 | turukhansk
# Processing Record 45 of Set 10 | zhigansk
# Processing Record 46 of Set 10 | neryungri
# Processing Record 47 of Set 10 | riyadh
# Processing Record 48 of Set 10 | ojinaga
# Processing Record 49 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 0 of Set 11 | san lorenzo
# Processing Record 1 of Set 11 | vallenar
# Processing Record 2 of Set 11 | minab
# Processing Record 3 of Set 11 | lafiagi
# Processing Record 4 of Set 11 | trelew
# Processing Record 5 of Set 11 | khromtau
# Processing Record 6 of Set 11 | awjilah
# Processing Record 7 of Set 11 | calabozo
# Processing Record 8 of Set 11 | mazatlan
# Processing Record 9 of Set 11 | hofn
# Processing Record 10 of Set 11 | kenora
# Processing Record 11 of Set 11 | kupang
# Processing Record 12 of Set 11 | horodnytsya
# Processing Record 13 of Set 11 | san andres
# Processing Record 14 of Set 11 | havelock
# Processing Record 15 of Set 11 | san jeronimo
# Processing Record 16 of Set 11 | meulaboh
# Processing Record 17 of Set 11 | ayia anna
# Processing Record 18 of Set 11 | diu
# Processing Record 19 of Set 11 | vigrestad
# Processing Record 20 of Set 11 | batagay-alyta
# Processing Record 21 of Set 11 | poso
# Processing Record 22 of Set 11 | nyurba
# Processing Record 23 of Set 11 | puro
# Processing Record 24 of Set 11 | tonantins
# Processing Record 25 of Set 11 | papar
# Processing Record 26 of Set 11 | nioro
# Processing Record 27 of Set 11 | zirovnice
# Processing Record 28 of Set 11 | alexander city
# Processing Record 29 of Set 11 | najran
# Processing Record 30 of Set 11 | chabahar
# Processing Record 31 of Set 11 | ostrovnoy
# Processing Record 32 of Set 11 | kisaran
# Processing Record 33 of Set 11 | penzberg
# Processing Record 34 of Set 11 | urumqi
# City not found. Skipping...
# Processing Record 35 of Set 11 | presidente epitacio
# Processing Record 36 of Set 11 | ocampo
# Processing Record 37 of Set 11 | lagoa
# Processing Record 38 of Set 11 | huilong
# Processing Record 39 of Set 11 | maymyo
# Processing Record 40 of Set 11 | mosjoen
# Processing Record 41 of Set 11 | arrifes
# Processing Record 42 of Set 11 | tazovskiy
# Processing Record 43 of Set 11 | ishigaki
# Processing Record 44 of Set 11 | linxia
# Processing Record 45 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 46 of Set 11 | yumbing
# Processing Record 47 of Set 11 | wanaka
# Processing Record 48 of Set 11 | oistins
# Processing Record 49 of Set 11 | uyuni
# Processing Record 0 of Set 12 | nouadhibou
# Processing Record 1 of Set 12 | chalus
# Processing Record 2 of Set 12 | bardiyah
# City not found. Skipping...
# Processing Record 3 of Set 12 | mayo
# Processing Record 4 of Set 12 | narsaq
# Processing Record 5 of Set 12 | sao miguel do araguaia
# Processing Record 6 of Set 12 | flin flon
# Processing Record 7 of Set 12 | tam ky
# Processing Record 8 of Set 12 | baghmara
# Processing Record 9 of Set 12 | tura
# Processing Record 10 of Set 12 | starodub
# Processing Record 11 of Set 12 | breytovo
# Processing Record 12 of Set 12 | kaeo
# Processing Record 13 of Set 12 | jalu
# Processing Record 14 of Set 12 | la tuque
# Processing Record 15 of Set 12 | lishu
# Processing Record 16 of Set 12 | ariquemes
# Processing Record 17 of Set 12 | port shepstone
# Processing Record 18 of Set 12 | yebaishou
# Processing Record 19 of Set 12 | ust-kuyga
# Processing Record 20 of Set 12 | dhidhdhoo
# Processing Record 21 of Set 12 | dreux
# Processing Record 22 of Set 12 | caibarien
# Processing Record 23 of Set 12 | kayerkan
# Processing Record 24 of Set 12 | algeciras
# Processing Record 25 of Set 12 | west plains
# Processing Record 26 of Set 12 | maloshuyka
# City not found. Skipping...
# Processing Record 27 of Set 12 | ulaanbaatar
# Processing Record 28 of Set 12 | dubenskiy
# City not found. Skipping...
# Processing Record 29 of Set 12 | mustafakemalpasa
# City not found. Skipping...
# Processing Record 30 of Set 12 | micheweni
# Processing Record 31 of Set 12 | sangin
# Processing Record 32 of Set 12 | muswellbrook
# Processing Record 33 of Set 12 | buraydah
# Processing Record 34 of Set 12 | rudnichnyy
# Processing Record 35 of Set 12 | omboue
# Processing Record 36 of Set 12 | luganville
# Processing Record 37 of Set 12 | sabha
# Processing Record 38 of Set 12 | jibuti
# City not found. Skipping...
# Processing Record 39 of Set 12 | huallanca
# Processing Record 40 of Set 12 | iberia
# Processing Record 41 of Set 12 | mount isa
# Processing Record 42 of Set 12 | bara
# Processing Record 43 of Set 12 | livingston
# Processing Record 44 of Set 12 | castanheira de pera
# Processing Record 45 of Set 12 | aitape
# Processing Record 46 of Set 12 | kavieng
# Processing Record 47 of Set 12 | chapais
# Processing Record 48 of Set 12 | arman

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
